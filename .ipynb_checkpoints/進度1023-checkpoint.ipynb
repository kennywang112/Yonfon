# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import pyproj
import geopandas as gpd
from shapely.geometry import Point

# %%
train = pd.read_csv("30_Training Dataset_V2/training_data.csv")
train.head()
# Out:
#      ID   縣市 鄉鎮市區      路名      土地面積  使用分區  移轉層次  總樓層數  主要用途    主要建材  ...  \
# 0  TR-1  台北市  大安區  敦化南路二段 -0.256716  None    11    11   住家用  鋼筋混凝土造  ...
# 1  TR-2  台北市  萬華區     水源路  0.100134  None     7    12   住家用  鋼筋混凝土造  ...
# 2  TR-3  高雄市  鳳山區     北忠街  0.181921  None    10    15  集合住宅      其他  ...
# 3  TR-4  新北市  新莊區     福前街  0.085594  None     9    14  集合住宅  鋼筋混凝土造  ...
# 4  TR-5  新北市  板橋區   文化路一段 -0.938116  None    41    43   住家用     鋼骨造  ...
#
#        建物面積      車位面積  車位個數     橫坐標      縱坐標   備註     主建物面積      陽台面積  \
# 0 -0.174154 -0.819326   0.0  305266  2768378  NaN  0.393926  0.183700
# 1  0.314204 -0.819326   0.0  300677  2767990  NaN -0.316131  0.608577
# 2  0.423366  0.161624   1.0  184815  2504666  NaN -0.098871 -0.360620
# 3  0.164249  0.524653   1.0  296653  2772355  NaN -0.071147  0.315088
# 4  0.985839  0.532377   1.0  297377  2768472  NaN  0.791954  1.719400
#
#      附屬建物面積        單價
# 0 -0.438452  4.627714
# 1 -0.438452  1.887258
# 2  1.525881  1.489072
# 3  0.231984  2.051217
# 4 -0.438452  3.269198
#
# [5 rows x 22 columns]

# %% [markdown]
# # 計算最近設施實際距離

# %%
facility_data = pd.read_csv("landmark.csv")
facility_data.head(5)
# Out:
#   縣市代號   縣市   大類別  小類別代號 小類別名稱       地標名稱         緯度          經度
# 0    A  臺北市  交通運輸     11   火車站  臺北市臺鐵南港車站  25.053541  121.607264
# 1    A  臺北市  交通運輸     11   火車站  臺北市臺鐵松山車站  25.049244  121.578933
# 2    A  臺北市  交通運輸     11   火車站  臺北市臺鐵臺北車站  25.047379  121.516891
# 3    A  臺北市  交通運輸     11   火車站      松山火車站  25.049388  121.579563
# 4    A  臺北市  交通運輸     11   火車站      南港火車站  25.053683  121.606943

# %%
facility_data.shape
# Out:
# (58323, 8)

# %% [markdown]
# ## 篩選重要設施
# - 交通：火車站、客運站、捷運站、高鐵站
# - 教育：國小、國中、幼稚園、托兒所
# - 公園：一般公園、里鄰公園
# - 娛樂：娛樂設施、商店、超級市場、大型購物中心、百貨公司
# - 其他：醫療保健、金融機構、加油站
# - 嫌惡設施：產業用水及設施、工廠、主要道路建設

# %%
facility_data['小類別名稱'].unique()
# Out:
# array(['火車站', '客運站', '捷運站', '飯店', '碼頭', '高鐵站', '航空站', '主要道路建設', '國小',
#        '國中', '高中', '專科', '大學及研究所', '幼稚園、托兒所', '傳統市場', '生活百貨量販', '一般公園',
#        '里鄰公園', '觀光遊憩設施', '停車場地', '服務性設施', '行政機關', '醫療保健', '加油站', '百貨公司',
#        '金融機構', '娛樂設施', '電力資源', '產業用水及設施', '工廠', '商店', '超級市場', '大型購物中心'],
#       dtype=object)

# %%
data = {}
for i in facility_data['小類別名稱'].unique():
    data['最近'+i] = []
df = pd.DataFrame(data)
df
# Out:
# Empty DataFrame
# Columns: [最近火車站, 最近客運站, 最近捷運站, 最近飯店, 最近碼頭, 最近高鐵站, 最近航空站, 最近主要道路建設, 最近國小, 最近國中, 最近高中, 最近專科, 最近大學及研究所, 最近幼稚園、托兒所, 最近傳統市場, 最近生活百貨量販, 最近一般公園, 最近里鄰公園, 最近觀光遊憩設施, 最近停車場地, 最近服務性設施, 最近行政機關, 最近醫療保健, 最近加油站, 最近百貨公司, 最近金融機構, 最近娛樂設施, 最近電力資源, 最近產業用水及設施, 最近工廠, 最近商店, 最近超級市場, 最近大型購物中心]
# Index: []
#
# [0 rows x 33 columns]

# %%
def train_coordination(x):
  x1, y1 = x['橫坐標'] ,x['縱坐標']
  proj = pyproj.Transformer.from_crs(3826, 4326, always_xy=True)
  x2, y2 = proj.transform(x1, y1)
  return x2, y2

train[['lon','lat']] = train.apply(train_coordination,axis=1,result_type='expand')
new_train = train.drop(['橫坐標','縱坐標'], axis=1)

# %%
# 轉換 train 和 facility_data 為 GeoDataFrame
train['geometry'] = [Point(xy) for xy in zip(train['lon'], train['lat'])]
train = gpd.GeoDataFrame(train, geometry='geometry')

# 設定crs座標 TWD97
facility_data = gpd.GeoDataFrame(facility_data, geometry=gpd.points_from_xy(facility_data['經度'], facility_data['緯度']))
facility_data.crs = "EPSG:3826"
new_train.crs = "EPSG:3826"

# %%
for i in facility_data['小類別名稱'].unique():
    # 選取特定設施，計算該設施對房子的最小距離
    specific_facility = facility_data[facility_data['小類別名稱']==i]

# %%
train
# Out:
#              ID   縣市 鄉鎮市區      路名      土地面積  使用分區  移轉層次  總樓層數  主要用途    主要建材  \
# 0          TR-1  台北市  大安區  敦化南路二段 -0.256716  None    11    11   住家用  鋼筋混凝土造
# 1          TR-2  台北市  萬華區     水源路  0.100134  None     7    12   住家用  鋼筋混凝土造
# 2          TR-3  高雄市  鳳山區     北忠街  0.181921  None    10    15  集合住宅      其他
# 3          TR-4  新北市  新莊區     福前街  0.085594  None     9    14  集合住宅  鋼筋混凝土造
# 4          TR-5  新北市  板橋區   文化路一段 -0.938116  None    41    43   住家用     鋼骨造
# ...         ...  ...  ...     ...       ...   ...   ...   ...   ...     ...
# 11746  TR-11747  桃園市  八德區   介壽路二段  0.706189    其他     4     5   住家用  鋼筋混凝土造
# 11747  TR-11748  新竹市  新竹市     東南街 -0.225809  None     2     7   住家用  鋼筋混凝土造
# 11748  TR-11749  新北市  汐止區     建成路 -0.943908  None    15    17   住家用  鋼筋混凝土造
# 11749  TR-11750  新北市  土城區     學士路 -1.147111  None    12    16   住家用  鋼筋混凝土造
# 11750  TR-11751  新北市  三重區    大同南路 -0.398154  None    11    27  集合住宅     鋼骨造
#
#        ...     橫坐標      縱坐標   備註     主建物面積      陽台面積    附屬建物面積        單價  \
# 0      ...  305266  2768378  NaN  0.393926  0.183700 -0.438452  4.627714
# 1      ...  300677  2767990  NaN -0.316131  0.608577 -0.438452  1.887258
# 2      ...  184815  2504666  NaN -0.098871 -0.360620  1.525881  1.489072
# 3      ...  296653  2772355  NaN -0.071147  0.315088  0.231984  2.051217
# 4      ...  297377  2768472  NaN  0.791954  1.719400 -0.438452  3.269198
# ...    ...     ...      ...  ...       ...       ...       ...       ...
# 11746  ...  280165  2758675  NaN  0.146962 -0.181455 -0.171559  0.903505
# 11747  ...  247333  2743084  NaN -0.181192 -0.067131 -0.163018  1.044041
# 11748  ...  316680  2773938  NaN -0.901999 -0.495421 -0.171559  2.144908
# 11749  ...  295794  2763966  NaN -1.333408 -0.708713 -0.438452  2.285444
# 11750  ...  300173  2772198  NaN  0.823638  0.968614 -0.438452  2.660207
#
#               lon        lat                    geometry
# 0      121.547608  25.022469  POINT (121.54761 25.02247)
# 1      121.502124  25.019127  POINT (121.50212 25.01913)
# 2      120.365799  22.640966  POINT (120.36580 22.64097)
# 3      121.462402  25.058663  POINT (121.46240 25.05866)
# 4      121.469444  25.023585  POINT (121.46944 25.02359)
# ...           ...        ...                         ...
# 11746  121.298684  24.935576  POINT (121.29868 24.93558)
# 11747  120.973622  24.795109  POINT (120.97362 24.79511)
# 11748  121.660968  25.072204  POINT (121.66097 25.07220)
# 11749  121.453610  24.982953  POINT (121.45361 24.98295)
# 11750  121.497284  25.057133  POINT (121.49728 25.05713)
#
# [11751 rows x 25 columns]

# %%
# 計算附近數量的函數
def min_nearby_facility_distance(point, facility_data, max_distance=500):
    
    full_distance = (facility_data.geometry.distance(point) * 101.77545 * 1000).sort_values().reset_index(drop=True)
    # print(full_distance[0])
    
    return full_distance[0]

train['facility'] = train.geometry.apply(min_nearby_facility_distance, facility_data = facility_data)
# min_nearby_facility_distance(train.geometry[0], facility_data)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [66], in <cell line: 9>()
#       5     # print(full_distance[0])
#       7     return full_distance[0]
# ----> 9 train['facility'] = train.geometry.apply(min_nearby_facility_distance, facility_data = facility_data)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/geopandas/geoseries.py:660, in GeoSeries.apply(self, func, convert_dtype, args, **kwargs)
#     657         kwargs["convert_dtype"] = True
#     659 # to avoid warning
# --> 660 result = super().apply(func, args=args, **kwargs)
#     661 if isinstance(result, GeoSeries):
#     662     if self.crs is not None:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/series.py:4433, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4323 def apply(
#    4324     self,
#    4325     func: AggFuncType,
#    (...)
#    4328     **kwargs,
#    4329 ) -> DataFrame | Series:
#    4330     """
#    4331     Invoke function on values of Series.
#    4332
#    (...)
#    4431     dtype: float64
#    4432     """
# -> 4433     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/apply.py:1088, in SeriesApply.apply(self)
#    1084 if isinstance(self.f, str):
#    1085     # if we are a string, try to dispatch
#    1086     return self.apply_str()
# -> 1088 return self.apply_standard()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/apply.py:1143, in SeriesApply.apply_standard(self)
#    1137         values = obj.astype(object)._values
#    1138         # error: Argument 2 to "map_infer" has incompatible type
#    1139         # "Union[Callable[..., Any], str, List[Union[Callable[..., Any], str]],
#    1140         # Dict[Hashable, Union[Union[Callable[..., Any], str],
#    1141         # List[Union[Callable[..., Any], str]]]]]"; expected
#    1142         # "Callable[[Any], Any]"
# -> 1143         mapped = lib.map_infer(
#    1144             values,
#    1145             f,  # type: ignore[arg-type]
#    1146             convert=self.convert_dtype,
#    1147         )
#    1149 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1150     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1151     #  See also GH#25959 regarding EA support
#    1152     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/lib.pyx:2870, in pandas._libs.lib.map_infer()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/apply.py:138, in Apply.__init__.<locals>.f(x)
#     137 def f(x):
# --> 138     return func(x, *args, **kwargs)
#
# Input In [66], in min_nearby_facility_distance(point, facility_data, max_distance)
#       2 def min_nearby_facility_distance(point, facility_data, max_distance=500):
# ----> 4     full_distance = (facility_data.geometry.distance(point) * 101.77545 * 1000).sort_values().reset_index(drop=True)
#       5     # print(full_distance[0])
#       7     return full_distance[0]
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/geopandas/base.py:2577, in GeoPandasBase.distance(self, other, align)
#    2483 def distance(self, other, align=True):
#    2484     """Returns a ``Series`` containing the distance to aligned `other`.
#    2485
#    2486     The operation works on a 1-to-1 row-wise manner:
#    (...)
#    2575     dtype: float64
#    2576     """
# -> 2577     return _binary_op("distance", self, other, align)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/geopandas/base.py:63, in _binary_op(op, this, other, align, *args, **kwargs)
#      60 def _binary_op(op, this, other, align, *args, **kwargs):
#      61     # type: (str, GeoSeries, GeoSeries, args/kwargs) -> Series[bool/float]
#      62     """Binary operation on GeoSeries objects that returns a Series"""
# ---> 63     data, index = _delegate_binary_method(op, this, other, align, *args, **kwargs)
#      64     return Series(data, index=index)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/geopandas/base.py:47, in _delegate_binary_method(op, this, other, align, *args, **kwargs)
#      44 else:
#      45     raise TypeError(type(this), type(other))
# ---> 47 data = getattr(a_this, op)(other, *args, **kwargs)
#      48 return data, this.index
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/geopandas/array.py:693, in GeometryArray.distance(self, other)
#     691 def distance(self, other):
#     692     self.check_geographic_crs(stacklevel=6)
# --> 693     return self._binary_method("distance", self, other)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/geopandas/array.py:611, in GeometryArray._binary_method(op, left, right, **kwargs)
#     608         _crs_mismatch_warn(left, right, stacklevel=7)
#     609     right = right._data
# --> 611 return getattr(vectorized, op)(left._data, right, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/geopandas/_vectorized.py:982, in distance(data, other)
#     980 def distance(data, other):
#     981     if compat.USE_SHAPELY_20:
# --> 982         return shapely.distance(data, other)
#     983     elif compat.USE_PYGEOS:
#     984         return _binary_method("distance", data, other)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/shapely/decorators.py:77, in multithreading_enabled.<locals>.wrapped(*args, **kwargs)
#      75     for arr in array_args:
#      76         arr.flags.writeable = False
# ---> 77     return func(*args, **kwargs)
#      78 finally:
#      79     for arr, old_flag in zip(array_args, old_flags):
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/shapely/measurement.py:72, in distance(a, b, **kwargs)
#      47 @multithreading_enabled
#      48 def distance(a, b, **kwargs):
#      49     """Computes the Cartesian distance between two geometries.
#      50
#      51     Parameters
#    (...)
#      70     nan
#      71     """
# ---> 72     return lib.distance(a, b, **kwargs)
#
# KeyboardInterrupt:
