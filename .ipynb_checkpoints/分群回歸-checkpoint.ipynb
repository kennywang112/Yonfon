# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import pyproj
import geopandas as gpd
from shapely.geometry import Point
from sklearn.linear_model import Lasso,LassoCV,Ridge
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
import numpy as np
from sklearn.metrics import accuracy_score
from sklearn import preprocessing
from sklearn.model_selection import train_test_split, GridSearchCV
import matplotlib.pyplot as plt

# %%
concat_data = pd.read_csv("new_concat_data.csv")

# %% [markdown]
# 臺北市、新北市、桃園市、臺中市、臺南市、高雄市、(新竹縣、新竹市)

# %%
for i in unique_city:
    print(i,concat_data[concat_data['縣市'] == i].shape)
# Out:
# 台北市 (1265, 60)
# 高雄市 (1310, 60)
# 新北市 (4156, 60)
# 桃園市 (1165, 60)
# 台中市 (982, 60)
# 台南市 (474, 60)
# 苗栗縣 (43, 60)
# 新竹縣 (347, 60)
# 基隆市 (222, 60)
# 屏東縣 (46, 60)
# 新竹市 (243, 60)
# 宜蘭縣 (75, 60)
# 花蓮縣 (12, 60)
# 嘉義市 (25, 60)
# 金門縣 (30, 60)
# 嘉義縣 (2, 60)
# 彰化縣 (20, 60)
# 雲林縣 (2, 60)

# %%
# 六都分一類
Taipei = concat_data[concat_data['縣市'] == "台北市"]
Kaohsiung = concat_data[concat_data['縣市'] == "高雄市"]
New_Taipei = concat_data[concat_data['縣市'] == "新北市"]
Taoyuan = concat_data[concat_data['縣市'] == "桃園市"]
Taichung = concat_data[concat_data['縣市'] == "台中市"]
Tainan = concat_data[concat_data['縣市'] == "台南市"]
Hsinchu = concat_data[(concat_data['縣市'] == "新竹縣") | (concat_data['縣市'] == "新竹市")]
Else = concat_data[(concat_data['縣市'] != "台北市") & (concat_data['縣市'] != "高雄市") & (concat_data['縣市'] != "新北市") & (concat_data['縣市'] != "桃園市") & (concat_data['縣市'] != "台中市") &( concat_data['縣市'] != "台南市") & (concat_data['縣市'] != "新竹縣") & (concat_data['縣市'] != "新竹市")]
multi = [Taipei, Kaohsiung, New_Taipei, Taoyuan, Taichung, Tainan, Hsinchu, Else]

# %%
Taipei.shape[0] + Kaohsiung.shape[0] + New_Taipei.shape[0] + Taoyuan.shape[0] + Taichung.shape[0] + Tainan.shape[0] + Else.shape[0] + Hsinchu.shape[0] == concat_data.shape[0]
# Out:
# True

# %%
def GetSplit(data):
    train_data, test_data = train_test_split(specific, random_state=777, train_size=0.8)

    Y_train = train_data[['單價']]
    X_train = train_data.drop(['單價'], axis=1)
    Y_test = test_data[['單價']]
    X_test = test_data.drop(['單價'], axis=1)
        
    return X_train, Y_train, X_test, Y_test

def ClusterTrainer(city):
    
    # specific = concat_data[concat_data['縣市'] == city]
    specific = city
    
    specific = specific[[
        '縣市', '鄉鎮市區', '路名', '主要用途', '主要建材', '建物型態', '使用分區', '備註', '單價',
        'lng', '最近航空站', '最近幼稚園、托兒所',
        '屋齡', '最近一般公園', '最近碼頭', '最近大型購物中心', 
        '最近超級市場', '最近大學及研究所', '總樓層數',
        '最近國中', '最近生活百貨量販',
        '最近捷運站', '最近電力資源', '最近高鐵站',
        '最近產業用水及設施', '最近飯店', '最近觀光遊憩設施', 
        '最近主要道路建設', 'lat', '最近里鄰公園', '最近娛樂設施', 
        '國中(高)', '國中(中)', '最近火車站', '車位面積', 
        '最近百貨公司', '陽台面積', '移轉層次', '最近停車場地', 
        '最近醫療保健', '最近金融機構', '最近加油站', 
        '土地面積', '主建物面積', '建物面積', '最近工廠', 
        '最近傳統市場', '附屬建物面積', '國中(下)', 
        '最近高中', '最近商店', '最近專科', '最近國小', 
        '最近廟宇距離', '最近金融機構距離'
    ]]
    specific = pd.get_dummies(specific, columns=['鄉鎮市區','路名','主要用途','主要建材','建物型態','使用分區','備註'])
    specific = specific.drop(['縣市'], axis=1)
    
    train_data, test_data = train_test_split(specific, random_state=777, train_size=0.8)

    # train_test_data = GetSplit(specific)
    Y_train = train_data[['單價']]
    X_train = train_data.drop(['單價'], axis=1)
    Y_test = test_data[['單價']]
    X_test = test_data.drop(['單價'], axis=1)

    ridge = Ridge()
    parameters = {'alpha':[1e-15,1e-10,1e-8,1e-3,1e-2,1,5,10,20,30,35,40,45,50,55,100]}
    ridge_reg = GridSearchCV(ridge,parameters,scoring='neg_mean_squared_error',cv=5)
    result = ridge_reg.fit(X_train.values, Y_train['單價'].values)
    
    return result, Y_test, X_test

# %%
test_res_list = []

for i in multi:
    res = ClusterTrainer(i)
    predictions = res[0].predict(res[2].values)
    test_res_list.append(np.mean(np.abs((res[1]['單價'].values - predictions) / res[1]['單價'].values)) * 100)
    np.mean(np.abs((res[1]['單價'].values - predictions) / res[1]['單價'].values)) * 100
# Out:
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.08355e-21): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=8.52677e-22): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=3.85013e-22): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=3.89044e-22): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=3.94978e-22): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.05435e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.00603e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.0178e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.04703e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.04531e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=6.11017e-22): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.30602e-21): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.34376e-21): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.38336e-21): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.32388e-21): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=6.10999e-20): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.30581e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.34359e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.38338e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.32391e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=6.78248e-23): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.27888e-22): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=6.7869e-23): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.26503e-22): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=6.92245e-23): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.60695e-20): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.57171e-20): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.60888e-20): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.60631e-20): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.58464e-20): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=2.22814e-22): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=2.94281e-22): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=4.97392e-22): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=2.85815e-22): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=2.50376e-22): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=2.22758e-20): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=2.94176e-20): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=4.18803e-20): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=2.85711e-20): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=2.50268e-20): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.07226e-21): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.22177e-21): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=5.53963e-22): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=7.3043e-22): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=7.16078e-22): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.37929e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.44394e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.37959e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.34946e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.37451e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.18269e-21): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.0931e-21): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=3.52577e-21): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.23462e-21): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.26424e-21): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.1771e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.32009e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=3.4713e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.13718e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=9.48654e-20): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.66333e-21): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.29044e-21): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.49889e-21): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.62706e-21): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.48519e-21): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.66337e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.31962e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=3.08682e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=2.9688e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=3.10138e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:196: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:196: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:196: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:196: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:196: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:196: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:196: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:196: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:196: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:196: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:196: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:196: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:196: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:196: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:196: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=1.78558e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=2.65259e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=1.25993e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=1.54563e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=2.01703e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)

# %%
print(test_res_list)
print(np.mean(test_res_list))
# Out:
# [7.993234653410479, 11.07400388442289, 7.861891382556029, 9.17748063381532, 11.391698668621421, 13.957342967804149, 13.818363002866105, 11.993905033375569]
# 10.908490028358996

# %% [markdown]
# ## 正式

# %%
concat_data = pd.read_csv("new_concat_data.csv")

# %%
concat_data
# Out:
#         縣市 鄉鎮市區     路名      土地面積  使用分區  移轉層次  總樓層數  主要用途    主要建材  \
# 0      台北市  萬華區    水源路  0.100134  None     7    12   住家用  鋼筋混凝土造
# 1      高雄市  鳳山區    北忠街  0.181921  None    10    15  集合住宅      其他
# 2      新北市  新莊區    福前街  0.085594  None     9    14  集合住宅  鋼筋混凝土造
# 3      台北市  萬華區    國興路  0.260510  None     2    12   住家用  鋼筋混凝土造
# 4      新北市  樹林區    信義街  0.856422  None     2     4   住家用  鋼筋混凝土造
# ...    ...  ...    ...       ...   ...   ...   ...   ...     ...
# 10414  桃園市  八德區  介壽路二段  0.706189    其他     4     5   住家用  鋼筋混凝土造
# 10415  新竹市  新竹市    東南街 -0.225809  None     2     7   住家用  鋼筋混凝土造
# 10416  新北市  汐止區    建成路 -0.943908  None    15    17   住家用  鋼筋混凝土造
# 10417  新北市  土城區    學士路 -1.147111  None    12    16   住家用  鋼筋混凝土造
# 10418  新北市  三重區   大同南路 -0.398154  None    11    27  集合住宅     鋼骨造
#
#                   建物型態  ...       最近娛樂設施         最近電力資源     最近產業用水及設施  \
# 0      住宅大樓(11層含以上有電梯)  ...   652.635054   97163.858484  91140.483076
# 1      住宅大樓(11層含以上有電梯)  ...  1559.977525    5113.742660   1343.918776
# 2      住宅大樓(11層含以上有電梯)  ...  2064.189161   98663.458620  95797.250255
# 3      住宅大樓(11層含以上有電梯)  ...   236.000039   97989.178309  91572.852428
# 4         公寓(5樓含以下無電梯)  ...   414.040551   89883.348426  89058.216769
# ...                ...  ...          ...            ...           ...
# 10414     公寓(5樓含以下無電梯)  ...  1710.102972   80263.605376  85192.933817
# 10415    華廈(10層含以下有電梯)  ...   701.764388   60371.470557  54175.583089
# 10416  住宅大樓(11層含以上有電梯)  ...  5517.793479  110716.641176  95484.678845
# 10417  住宅大樓(11層含以上有電梯)  ...  2652.481829   91484.577134  88429.041654
# 10418  住宅大樓(11層含以上有電梯)  ...   757.346454  100245.021269  95038.443204
#
#                 最近工廠           最近商店        最近超級市場       最近大型購物中心        單價  \
# 0      136458.703475  169114.219348   5745.826358   44430.815619  1.887258
# 1        2903.279491     155.658006    827.162783  129753.557176  1.489072
# 2      140391.552888  171151.625585   7679.115919   50100.306317  2.051217
# 3      137028.451622  169899.389221   6628.058791   44431.810363  2.238599
# 4      132618.369151  162396.287236   3630.841437   44903.430177  1.348536
# ...              ...            ...           ...            ...       ...
# 10414  128810.504307  153456.518531  16973.628093   31524.539728  0.903505
# 10415  123565.866291  129064.825771  52933.989221     185.577977  1.044041
# 10416  143350.243687  181232.023292  22506.447487   41803.565118  2.144908
# 10417  132682.299429  163725.439724    497.164625   45039.429924  2.285444
# 10418  140307.223185  172430.064523   8487.699282   47809.536385  2.660207
#
#          最近金融機構距離       最近廟宇距離
# 0      464.838830   511.010936
# 1      282.164695   167.522910
# 2      240.672461   349.220965
# 3      384.139648    62.395726
# 4      344.240245   303.258173
# ...           ...          ...
# 10414  100.977778  1539.394150
# 10415   51.131862   159.959954
# 10416  229.586628   279.229819
# 10417  157.822673   394.627766
# 10418  358.540959   270.656913
#
# [10419 rows x 60 columns]

# %%
# 六都分一類
Taipei = concat_data[concat_data['縣市'] == "台北市"]
Kaohsiung = concat_data[concat_data['縣市'] == "高雄市"]
New_Taipei = concat_data[concat_data['縣市'] == "新北市"]
Taoyuan = concat_data[concat_data['縣市'] == "桃園市"]
Taichung = concat_data[concat_data['縣市'] == "台中市"]
Tainan = concat_data[concat_data['縣市'] == "台南市"]
Hsinchu = concat_data[(concat_data['縣市'] == "新竹縣") | (concat_data['縣市'] == "新竹市")]
Else = concat_data[(concat_data['縣市'] != "台北市") & (concat_data['縣市'] != "高雄市") & (concat_data['縣市'] != "新北市") & (concat_data['縣市'] != "桃園市") & (concat_data['縣市'] != "台中市") &( concat_data['縣市'] != "台南市") & (concat_data['縣市'] != "新竹縣") & (concat_data['縣市'] != "新竹市")]
multi = [Taipei, Kaohsiung, New_Taipei, Taoyuan, Taichung, Tainan, Hsinchu, Else]

# %%
def ClusterTrainer(city):
    
    # specific = concat_data[concat_data['縣市'] == city]
    specific = city
    
    specific = specific[[
        '縣市', '鄉鎮市區', '路名', '主要用途', '主要建材', '建物型態', '使用分區', '備註', '單價',
        'lng', '最近航空站', '最近幼稚園、托兒所',
        '屋齡', '最近一般公園', '最近碼頭', '最近大型購物中心', 
        '最近超級市場', '最近大學及研究所', '總樓層數',
        '最近國中', '最近生活百貨量販',
        '最近捷運站', '最近電力資源', '最近高鐵站',
        '最近產業用水及設施', '最近飯店', '最近觀光遊憩設施', 
        '最近主要道路建設', 'lat', '最近里鄰公園', '最近娛樂設施', 
        '國中(高)', '國中(中)', '最近火車站', '車位面積', 
        '最近百貨公司', '陽台面積', '移轉層次', '最近停車場地', 
        '最近醫療保健', '最近金融機構', '最近加油站', 
        '土地面積', '主建物面積', '建物面積', '最近工廠', 
        '最近傳統市場', '附屬建物面積', '國中(下)', 
        '最近高中', '最近商店', '最近專科', '最近國小', 
        '最近廟宇距離', '最近金融機構距離'
    ]]
    specific = pd.get_dummies(specific, columns=['鄉鎮市區','路名','主要用途','主要建材','建物型態','使用分區','備註'])
    specific = specific.drop(['縣市'], axis=1)
    
    train_data, test_data = train_test_split(specific, random_state=777, train_size=0.8)

    # train_test_data = GetSplit(specific)
    Y_train = train_data[['單價']]
    X_train = train_data.drop(['單價'], axis=1)
    Y_test = test_data[['單價']]
    X_test = test_data.drop(['單價'], axis=1)

    ridge = Ridge()
    parameters = {'alpha':[1e-15,1e-10,1e-8,1e-3,1e-2,1,5,10,20,30,35,40,45,50,55,100]}
    ridge_reg = GridSearchCV(ridge,parameters,scoring='neg_mean_squared_error',cv=5)
    result = ridge_reg.fit(X_train.values, Y_train['單價'].values)
    
    return result, Y_test, X_test
